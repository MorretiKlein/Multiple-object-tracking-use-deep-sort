# %%
import torch
import numpy as np
import matplotlib.pyplot as plt
import cv2
import ultralytics
from ultralytics import YOLO
import random
import colorsys

# %%
from detection import Detection
from image_encode import Extractor
from iou_matching import iou, iou_cost
from kalman_filter import KalmanFilter
from linear_sum_assignment import gate_cost_matrix, matching_cascade, min_cost_matching
from nearest_neighbor_matching import NearestNeighborDistanceMetric
from track import Track
from tracker import Tracker

# %%
NUM_CLASS = {
    0: 'person'}
key_list = list(NUM_CLASS.keys()) 
val_list = list(NUM_CLASS.values())

# %%
def _interval_overlap(interval_a, interval_b):
    x1, x2 = interval_a
    x3, x4 = interval_b
    if x3 < x1:
        if x4 < x1:
            return 0
        else:
            return min(x2,x4) - x1
    else:
        if x2 < x3:
            return 0
        else:
            return min(x2,x4) - x3

def bbox_iou(box1, box2):
    intersect_w = _interval_overlap([box1[0], box1[1]], [box2[0], box2[1]])
    intersect_h = _interval_overlap([box1[2], box1[3]], [box2[2], box2[3]])
    intersect = intersect_w * intersect_h
    union = (box1[1]-box1[0])*(box1[3]-box1[2]) + (box2[1]-box2[0])*(box2[3]-box2[2]) - intersect
    return float(intersect) / union +0.01

def do_nms(boxes, nms_thresh):
    for i, box in enumerate(boxes):
        if box is None:
            continue
        for j in range(i + 1, len(boxes)):
            if boxes[j] is None:
                continue
            if bbox_iou(box, boxes[j]) >= nms_thresh:
                boxes[j] = None
    return boxes

# %%
def crop_image(image, bboxes):
    encoder = Extractor("ckpt.t7", use_cuda=True)
    im_crops = []
    for box in bboxes:
        x1,y1,x2,y2 = box
        x1,y1,x2,y2 = int(box[0] *640), int(box[1] * 640), int(box[2] * 640) , int(box[3] * 640)
        img = image[x1:x2, y1:y2]
        im_crops.append(img)
    if im_crops:
        features = encoder(im_crops)
    else:
        features = np.array([])
    return features

# %%
from draw import draw_bbox

max_cosine_distance = 0.4
nn_budget = None
# model = YOLO('test_temp/runs/detect/yolov8s_custom/weights/best.pt')
model = YOLO('yolov8n.pt')

def object_tracking():
    metric = NearestNeighborDistanceMetric("cosine", max_cosine_distance, nn_budget)
    tracker = Tracker(metric)

    cap = cv2.VideoCapture(0)  
    
    fourcc = cv2.VideoWriter_fourcc(*'mp4v')
    out = cv2.VideoWriter('output_video.mp4', fourcc, fps =20, frameSize = (640, 640))
    while True:
        ret, frame = cap.read()

        # frame = cv2.resize(frame, (640,640))
        frame = cv2.cvtColor(frame, cv2.COLOR_BGR2RGB)
        
        # detect
        boxes, labels, scores = [], [], []
        yhat = model.predict(source= frame)
        bboxes = yhat[0].boxes
        array_xyxy, array_conf = bboxes.xyxyn, bboxes.conf
        for i in range(array_xyxy.shape[0]):
            xmin, ymin , xmax, ymax = array_xyxy[i].cpu().numpy().tolist()
            # xmin, ymin , xmax, ymax = int(xmin), int(ymin), int(xmax), int(ymax)
            boxes.append((xmin, ymin , xmax, ymax))
            scores.append(array_conf[i].cpu().numpy())
            labels.append("person")
        boxes = do_nms(boxes, 0.3)
        boxes = [box for box in boxes if box is not None]
        boxes = np.array(boxes) 
        names = np.array(labels)
        scores = np.array(scores)
        features = np.array(crop_image(frame, boxes))
        detections = [Detection(bbox, score, class_name, feature) for bbox, score, class_name, feature in zip(boxes, scores, names, features)]

        tracker.predict()
        tracker.update(detections)
        
        tracked_bboxes = []
        for track in tracker.tracks:
            if not track.is_confirmed() or track.time_since_update > 1:
                continue 
            print("____________________________________________________________________")
            bbox = track.to_xyxy() 
            class_name = track.get_class() 
            tracking_id = track.track_id
            index = key_list[val_list.index(class_name)] 
            tracked_bboxes.append(bbox.tolist() + [tracking_id, index])
        image = draw_bbox(frame, tracked_bboxes, CLASSES=NUM_CLASS, show_label= True, show_confidence=False, tracking=True)
        image = cv2.cvtColor(image, cv2.COLOR_RGB2BGR)
        out.write(image)

        cv2.imshow("predict", image)
        if cv2.waitKey(1) & 0xFF == ord('q'):
            break
    
    cap.release()
    cv2.destroyAllWindows()
object_tracking()
# Out:
# 0: 480x640 1 person, 187.0ms
# Speed: 2.9ms preprocess, 187.0ms inference, 183.9ms postprocess per image at shape (1, 3, 480, 640)
# Loading weights from ckpt.t7... Done!
#
# 0: 480x640 1 person, 16.0ms
# Speed: 0.0ms preprocess, 16.0ms inference, 7.7ms postprocess per image at shape (1, 3, 480, 640)
# Loading weights from ckpt.t7... Done!
#
# 0: 480x640 1 person, 13.7ms
# Speed: 0.0ms preprocess, 13.7ms inference, 17.1ms postprocess per image at shape (1, 3, 480, 640)
# Loading weights from ckpt.t7... Done!
# ____________________________________________________________________
#  1
#
# 0: 480x640 1 person, 24.0ms
# Speed: 0.0ms preprocess, 24.0ms inference, 7.9ms postprocess per image at shape (1, 3, 480, 640)
# Loading weights from ckpt.t7... Done!
# ____________________________________________________________________
#  1
#
# 0: 480x640 1 person, 20.0ms
# Speed: 0.0ms preprocess, 20.0ms inference, 4.0ms postprocess per image at shape (1, 3, 480, 640)
# Loading weights from ckpt.t7... Done!
# ____________________________________________________________________
#  1
#
# 0: 480x640 1 person, 17.8ms
# Speed: 0.0ms preprocess, 17.8ms inference, 6.0ms postprocess per image at shape (1, 3, 480, 640)
# Loading weights from ckpt.t7... Done!
# ____________________________________________________________________
#  1
#
# 0: 480x640 1 person, 6.2ms
# Speed: 5.1ms preprocess, 6.2ms inference, 7.8ms postprocess per image at shape (1, 3, 480, 640)
# Loading weights from ckpt.t7... Done!
# ____________________________________________________________________
#  1
#
# 0: 480x640 1 person, 14.3ms
# Speed: 5.9ms preprocess, 14.3ms inference, 5.7ms postprocess per image at shape (1, 3, 480, 640)
# Loading weights from ckpt.t7... Done!
# ____________________________________________________________________
#  1
#
# 0: 480x640 1 person, 24.0ms
# Speed: 0.0ms preprocess, 24.0ms inference, 9.4ms postprocess per image at shape (1, 3, 480, 640)
# Loading weights from ckpt.t7... Done!
# ____________________________________________________________________
#  1
#
# 0: 480x640 1 person, 22.7ms
# Speed: 0.0ms preprocess, 22.7ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
# Loading weights from ckpt.t7... Done!
# ____________________________________________________________________
#  1
#
# 0: 480x640 1 person, 15.6ms
# Speed: 0.0ms preprocess, 15.6ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
# Loading weights from ckpt.t7... Done!
# ____________________________________________________________________
#  1
#
# 0: 480x640 1 person, 14.0ms
# Speed: 0.0ms preprocess, 14.0ms inference, 14.4ms postprocess per image at shape (1, 3, 480, 640)
# Loading weights from ckpt.t7... Done!
# ____________________________________________________________________
#  1
#
# 0: 480x640 1 person, 14.9ms
# Speed: 2.1ms preprocess, 14.9ms inference, 2.5ms postprocess per image at shape (1, 3, 480, 640)
# Loading weights from ckpt.t7... Done!
# ____________________________________________________________________
#  1
#
# 0: 480x640 1 person, 7.8ms
# Speed: 2.4ms preprocess, 7.8ms inference, 2.8ms postprocess per image at shape (1, 3, 480, 640)
# Loading weights from ckpt.t7... Done!
# ____________________________________________________________________
#  1
#
# 0: 480x640 1 person, 9.0ms
# Speed: 0.0ms preprocess, 9.0ms inference, 12.3ms postprocess per image at shape (1, 3, 480, 640)
# Loading weights from ckpt.t7... Done!
# ____________________________________________________________________
#  1
#
# 0: 480x640 1 person, 12.8ms
# Speed: 0.0ms preprocess, 12.8ms inference, 3.0ms postprocess per image at shape (1, 3, 480, 640)
# Loading weights from ckpt.t7... Done!
# ____________________________________________________________________
#  1
#
# 0: 480x640 1 person, 14.6ms
# Speed: 0.0ms preprocess, 14.6ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
# Loading weights from ckpt.t7... Done!
# ____________________________________________________________________
#  1
#
# 0: 480x640 1 person, 6.5ms
# Speed: 0.0ms preprocess, 6.5ms inference, 3.5ms postprocess per image at shape (1, 3, 480, 640)
# Loading weights from ckpt.t7... Done!
# ____________________________________________________________________
#  1
#
# 0: 480x640 1 person, 7.8ms
# Speed: 0.8ms preprocess, 7.8ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
# Loading weights from ckpt.t7... Done!
# ____________________________________________________________________
#  1
#
# 0: 480x640 1 person, 10.0ms
# Speed: 0.0ms preprocess, 10.0ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
# Loading weights from ckpt.t7... Done!
# ____________________________________________________________________
#  1
#
# 0: 480x640 1 person, 5.1ms
# Speed: 0.0ms preprocess, 5.1ms inference, 5.0ms postprocess per image at shape (1, 3, 480, 640)
# Loading weights from ckpt.t7... Done!
# ____________________________________________________________________
#  1
#
# 0: 480x640 1 person, 14.8ms
# Speed: 0.0ms preprocess, 14.8ms inference, 3.8ms postprocess per image at shape (1, 3, 480, 640)
# Loading weights from ckpt.t7... Done!
# ____________________________________________________________________
#  1
#
# 0: 480x640 1 person, 8.0ms
# Speed: 0.0ms preprocess, 8.0ms inference, 2.3ms postprocess per image at shape (1, 3, 480, 640)
# Loading weights from ckpt.t7... Done!
# ____________________________________________________________________
#  1
#
# 0: 480x640 1 person, 9.0ms
# Speed: 0.0ms preprocess, 9.0ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
# Loading weights from ckpt.t7... Done!
# ____________________________________________________________________
#  1
#
# 0: 480x640 1 person, 14.5ms
# Speed: 1.1ms preprocess, 14.5ms inference, 1.3ms postprocess per image at shape (1, 3, 480, 640)
# Loading weights from ckpt.t7... Done!
# ____________________________________________________________________
#  1
#
# 0: 480x640 1 person, 12.2ms
# Speed: 0.0ms preprocess, 12.2ms inference, 1.7ms postprocess per image at shape (1, 3, 480, 640)
# Loading weights from ckpt.t7... Done!
# ____________________________________________________________________
#  1
#
# 0: 480x640 1 person, 10.0ms
# Speed: 0.0ms preprocess, 10.0ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
# Loading weights from ckpt.t7... Done!
# ____________________________________________________________________
#  1
#
# 0: 480x640 1 person, 13.2ms
# Speed: 0.0ms preprocess, 13.2ms inference, 1.9ms postprocess per image at shape (1, 3, 480, 640)
# Loading weights from ckpt.t7... Done!
# ____________________________________________________________________
#  1
#
# 0: 480x640 1 person, 9.1ms
# Speed: 0.0ms preprocess, 9.1ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
# Loading weights from ckpt.t7... Done!
# ____________________________________________________________________
#  1
#
# 0: 480x640 1 person, 10.2ms
# Speed: 0.0ms preprocess, 10.2ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
# Loading weights from ckpt.t7... Done!
# ____________________________________________________________________
#  1
#
# 0: 480x640 1 person, 10.4ms
# Speed: 0.0ms preprocess, 10.4ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
# Loading weights from ckpt.t7... Done!
# ____________________________________________________________________
#  1
#
# 0: 480x640 1 person, 10.0ms
# Speed: 0.0ms preprocess, 10.0ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
# Loading weights from ckpt.t7... Done!
# ____________________________________________________________________
#  1
#
# 0: 480x640 1 person, 10.0ms
# Speed: 0.0ms preprocess, 10.0ms inference, 1.3ms postprocess per image at shape (1, 3, 480, 640)
# Loading weights from ckpt.t7... Done!
# ____________________________________________________________________
#  1
#
# 0: 480x640 1 person, 10.4ms
# Speed: 0.0ms preprocess, 10.4ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
# Loading weights from ckpt.t7... Done!
# ____________________________________________________________________
#  1
#
# 0: 480x640 1 person, 14.2ms
# Speed: 0.0ms preprocess, 14.2ms inference, 0.4ms postprocess per image at shape (1, 3, 480, 640)
# Loading weights from ckpt.t7... Done!
# ____________________________________________________________________
#  1
#
# 0: 480x640 1 person, 10.0ms
# Speed: 0.0ms preprocess, 10.0ms inference, 2.8ms postprocess per image at shape (1, 3, 480, 640)
# Loading weights from ckpt.t7... Done!
# ____________________________________________________________________
#  1
#
# 0: 480x640 1 person, 4.2ms
# Speed: 0.0ms preprocess, 4.2ms inference, 6.8ms postprocess per image at shape (1, 3, 480, 640)
# Loading weights from ckpt.t7... Done!
# ____________________________________________________________________
#  1
#
# 0: 480x640 1 person, 10.0ms
# Speed: 0.0ms preprocess, 10.0ms inference, 1.3ms postprocess per image at shape (1, 3, 480, 640)
# Loading weights from ckpt.t7... Done!
# ____________________________________________________________________
#  1
#
# 0: 480x640 1 person, 9.5ms
# Speed: 0.0ms preprocess, 9.5ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
# Loading weights from ckpt.t7... Done!
# ____________________________________________________________________
#  1
#
# 0: 480x640 1 person, 10.6ms
# Speed: 0.0ms preprocess, 10.6ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
# Loading weights from ckpt.t7... Done!
# ____________________________________________________________________
#  1
#
# 0: 480x640 1 person, 10.0ms
# Speed: 0.0ms preprocess, 10.0ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
# Loading weights from ckpt.t7... Done!
# ____________________________________________________________________
#  1
#
# 0: 480x640 1 person, 8.4ms
# Speed: 1.4ms preprocess, 8.4ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
# Loading weights from ckpt.t7... Done!
# ____________________________________________________________________
#  1
#
# 0: 480x640 1 person, 6.6ms
# Speed: 0.0ms preprocess, 6.6ms inference, 4.1ms postprocess per image at shape (1, 3, 480, 640)
# Loading weights from ckpt.t7... Done!
# ____________________________________________________________________
#  1
#
# 0: 480x640 1 person, 10.1ms
# Speed: 0.0ms preprocess, 10.1ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
# Loading weights from ckpt.t7... Done!
# ____________________________________________________________________
#  1
#
# 0: 480x640 1 person, 10.1ms
# Speed: 0.0ms preprocess, 10.1ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
# Loading weights from ckpt.t7... Done!
# ____________________________________________________________________
#  1
#
# 0: 480x640 1 person, 10.1ms
# Speed: 0.0ms preprocess, 10.1ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
# Loading weights from ckpt.t7... Done!
# ____________________________________________________________________
#  1
#
# 0: 480x640 1 person, 11.5ms
# Speed: 0.0ms preprocess, 11.5ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
# Loading weights from ckpt.t7... Done!
# ____________________________________________________________________
#  1
#
# 0: 480x640 1 person, 6.8ms
# Speed: 2.3ms preprocess, 6.8ms inference, 2.4ms postprocess per image at shape (1, 3, 480, 640)
# Loading weights from ckpt.t7... Done!
# ____________________________________________________________________
#  1
#
# 0: 480x640 1 person, 11.2ms
# Speed: 0.0ms preprocess, 11.2ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
# Loading weights from ckpt.t7... Done!
# ____________________________________________________________________
#  1
#
# 0: 480x640 1 person, 10.1ms
# Speed: 0.0ms preprocess, 10.1ms inference, 0.6ms postprocess per image at shape (1, 3, 480, 640)
# Loading weights from ckpt.t7... Done!
# ____________________________________________________________________
#  1
#
# 0: 480x640 1 person, 10.9ms
# Speed: 0.0ms preprocess, 10.9ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
# Loading weights from ckpt.t7... Done!
# ____________________________________________________________________
#  1
#
# 0: 480x640 1 person, 10.1ms
# Speed: 0.0ms preprocess, 10.1ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
# Loading weights from ckpt.t7... Done!
# ____________________________________________________________________
#  1
#
# 0: 480x640 1 person, 10.0ms
# Speed: 0.0ms preprocess, 10.0ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
# Loading weights from ckpt.t7... Done!
# ____________________________________________________________________
#  1
#
# 0: 480x640 1 person, 10.0ms
# Speed: 0.0ms preprocess, 10.0ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
# Loading weights from ckpt.t7... Done!
# ____________________________________________________________________
#  1
#
# 0: 480x640 1 person, 12.4ms
# Speed: 0.0ms preprocess, 12.4ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
# Loading weights from ckpt.t7... Done!
# ____________________________________________________________________
#  1
#
# 0: 480x640 1 person, 11.8ms
# Speed: 0.0ms preprocess, 11.8ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
# Loading weights from ckpt.t7... Done!
# ____________________________________________________________________
#  1
#
# 0: 480x640 1 person, 10.8ms
# Speed: 0.0ms preprocess, 10.8ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
# Loading weights from ckpt.t7... Done!
# ____________________________________________________________________
#  1
#
# 0: 480x640 1 person, 10.1ms
# Speed: 0.0ms preprocess, 10.1ms inference, 3.9ms postprocess per image at shape (1, 3, 480, 640)
# Loading weights from ckpt.t7... Done!
# ____________________________________________________________________
#  1
#
# 0: 480x640 1 person, 10.2ms
# Speed: 0.0ms preprocess, 10.2ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
# Loading weights from ckpt.t7... Done!
# ____________________________________________________________________
#  1
#
# 0: 480x640 1 person, 10.1ms
# Speed: 0.0ms preprocess, 10.1ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
# Loading weights from ckpt.t7... Done!
# ____________________________________________________________________
#  1
#
# 0: 480x640 1 person, 9.0ms
# Speed: 0.0ms preprocess, 9.0ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
# Loading weights from ckpt.t7... Done!
# ____________________________________________________________________
#  1
#
# 0: 480x640 1 person, 0.0ms
# Speed: 0.0ms preprocess, 0.0ms inference, 10.0ms postprocess per image at shape (1, 3, 480, 640)
# Loading weights from ckpt.t7... Done!
# ____________________________________________________________________
#  1
#
# 0: 480x640 1 person, 6.8ms
# Speed: 2.2ms preprocess, 6.8ms inference, 1.1ms postprocess per image at shape (1, 3, 480, 640)
# Loading weights from ckpt.t7... Done!
# ____________________________________________________________________
#  1
#
# 0: 480x640 1 person, 16.4ms
# Speed: 0.0ms preprocess, 16.4ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
# Loading weights from ckpt.t7... Done!
# ____________________________________________________________________
#  1
#
# 0: 480x640 1 person, 10.0ms
# Speed: 0.0ms preprocess, 10.0ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
# Loading weights from ckpt.t7... Done!
# ____________________________________________________________________
#  1
#
# 0: 480x640 1 person, 13.3ms
# Speed: 3.9ms preprocess, 13.3ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
# Loading weights from ckpt.t7... Done!
# ____________________________________________________________________
#  1
#
# 0: 480x640 1 person, 8.8ms
# Speed: 0.0ms preprocess, 8.8ms inference, 1.9ms postprocess per image at shape (1, 3, 480, 640)
# Loading weights from ckpt.t7... Done!
# ____________________________________________________________________
#  1
#
# 0: 480x640 1 person, 10.1ms
# Speed: 0.0ms preprocess, 10.1ms inference, 2.9ms postprocess per image at shape (1, 3, 480, 640)
# Loading weights from ckpt.t7... Done!
# ____________________________________________________________________
#  1
#
# 0: 480x640 1 person, 10.0ms
# Speed: 0.0ms preprocess, 10.0ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
# Loading weights from ckpt.t7... Done!
# ____________________________________________________________________
#  1
#
# 0: 480x640 1 person, 10.0ms
# Speed: 0.0ms preprocess, 10.0ms inference, 2.8ms postprocess per image at shape (1, 3, 480, 640)
# Loading weights from ckpt.t7... Done!
# ____________________________________________________________________
#  1
#
# 0: 480x640 1 person, 10.0ms
# Speed: 0.0ms preprocess, 10.0ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
# Loading weights from ckpt.t7... Done!
# ____________________________________________________________________
#  1
#
# 0: 480x640 1 person, 10.0ms
# Speed: 0.0ms preprocess, 10.0ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
# Loading weights from ckpt.t7... Done!
# ____________________________________________________________________
#  1
#
# 0: 480x640 1 person, 6.2ms
# Speed: 3.5ms preprocess, 6.2ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
# Loading weights from ckpt.t7... Done!
# ____________________________________________________________________
#  1
#
# 0: 480x640 1 person, 6.9ms
# Speed: 2.8ms preprocess, 6.9ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
# Loading weights from ckpt.t7... Done!
# ____________________________________________________________________
#  1
#
# 0: 480x640 1 person, 7.2ms
# Speed: 0.0ms preprocess, 7.2ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
# Loading weights from ckpt.t7... Done!
# ____________________________________________________________________
#  1
#
# 0: 480x640 1 person, 6.5ms
# Speed: 0.0ms preprocess, 6.5ms inference, 4.7ms postprocess per image at shape (1, 3, 480, 640)
# Loading weights from ckpt.t7... Done!
# ____________________________________________________________________
#  1
#
# 0: 480x640 1 person, 10.8ms
# Speed: 0.0ms preprocess, 10.8ms inference, 1.1ms postprocess per image at shape (1, 3, 480, 640)
# Loading weights from ckpt.t7... Done!
# ____________________________________________________________________
#  1
#
# 0: 480x640 1 person, 0.0ms
# Speed: 0.0ms preprocess, 0.0ms inference, 10.0ms postprocess per image at shape (1, 3, 480, 640)
# Loading weights from ckpt.t7... Done!
# ____________________________________________________________________
#  1
#
# 0: 480x640 1 person, 9.2ms
# Speed: 1.2ms preprocess, 9.2ms inference, 2.3ms postprocess per image at shape (1, 3, 480, 640)
# Loading weights from ckpt.t7... Done!
# ____________________________________________________________________
#  1
#
# 0: 480x640 2 persons, 10.0ms
# Speed: 0.0ms preprocess, 10.0ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
# Loading weights from ckpt.t7... Done!
# ____________________________________________________________________
#  1
#
# 0: 480x640 1 person, 8.2ms
# Speed: 0.0ms preprocess, 8.2ms inference, 6.3ms postprocess per image at shape (1, 3, 480, 640)
# Loading weights from ckpt.t7... Done!
# ____________________________________________________________________
#  1
#
# 0: 480x640 1 person, 10.0ms
# Speed: 0.0ms preprocess, 10.0ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
# Loading weights from ckpt.t7... Done!
# ____________________________________________________________________
#  1
#
# 0: 480x640 1 person, 0.0ms
# Speed: 0.0ms preprocess, 0.0ms inference, 10.0ms postprocess per image at shape (1, 3, 480, 640)
# Loading weights from ckpt.t7... Done!
# ____________________________________________________________________
#  1
#
# 0: 480x640 1 person, 7.3ms
# Speed: 1.5ms preprocess, 7.3ms inference, 3.5ms postprocess per image at shape (1, 3, 480, 640)
# Loading weights from ckpt.t7... Done!
# ____________________________________________________________________
#  1
#
# 0: 480x640 1 person, 10.0ms
# Speed: 0.0ms preprocess, 10.0ms inference, 4.3ms postprocess per image at shape (1, 3, 480, 640)
# Loading weights from ckpt.t7... Done!
# ____________________________________________________________________
#  1
#
# 0: 480x640 1 person, 10.5ms
# Speed: 0.0ms preprocess, 10.5ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
# Loading weights from ckpt.t7... Done!
# ____________________________________________________________________
#  1
#
# 0: 480x640 1 person, 10.9ms
# Speed: 0.0ms preprocess, 10.9ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
# Loading weights from ckpt.t7... Done!
# ____________________________________________________________________
#  1
#
# 0: 480x640 1 person, 9.5ms
# Speed: 0.0ms preprocess, 9.5ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
# Loading weights from ckpt.t7... Done!
# ____________________________________________________________________
#  1
#
# 0: 480x640 1 person, 9.8ms
# Speed: 2.3ms preprocess, 9.8ms inference, 1.5ms postprocess per image at shape (1, 3, 480, 640)
# Loading weights from ckpt.t7... Done!
# ____________________________________________________________________
#  1
#
# 0: 480x640 1 person, 8.8ms
# Speed: 0.0ms preprocess, 8.8ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
# Loading weights from ckpt.t7... Done!
# ____________________________________________________________________
#  1
#
# 0: 480x640 1 person, 13.1ms
# Speed: 0.0ms preprocess, 13.1ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
# Loading weights from ckpt.t7... Done!
# ____________________________________________________________________
#  1
#
# 0: 480x640 1 person, 6.1ms
# Speed: 3.2ms preprocess, 6.1ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
# Loading weights from ckpt.t7... Done!
# ____________________________________________________________________
#  1
#
# 0: 480x640 1 person, 10.0ms
# Speed: 0.0ms preprocess, 10.0ms inference, 5.3ms postprocess per image at shape (1, 3, 480, 640)
# Loading weights from ckpt.t7... Done!
# ____________________________________________________________________
#  1
#
# 0: 480x640 1 person, 10.2ms
# Speed: 0.0ms preprocess, 10.2ms inference, 0.7ms postprocess per image at shape (1, 3, 480, 640)
# Loading weights from ckpt.t7... Done!
# ____________________________________________________________________
#  1
#
# 0: 480x640 1 person, 10.5ms
# Speed: 0.0ms preprocess, 10.5ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
# Loading weights from ckpt.t7... Done!
# ____________________________________________________________________
#  1
#
# 0: 480x640 1 person, 10.0ms
# Speed: 0.0ms preprocess, 10.0ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
# Loading weights from ckpt.t7... Done!
# ____________________________________________________________________
#  1
#
# 0: 480x640 1 person, 10.0ms
# Speed: 0.0ms preprocess, 10.0ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
# Loading weights from ckpt.t7... Done!
# ____________________________________________________________________
#  1
#
# 0: 480x640 1 person, 10.3ms
# Speed: 0.0ms preprocess, 10.3ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
# Loading weights from ckpt.t7... Done!
# ____________________________________________________________________
#  1
#
# 0: 480x640 1 person, 7.4ms
# Speed: 2.3ms preprocess, 7.4ms inference, 1.1ms postprocess per image at shape (1, 3, 480, 640)
# Loading weights from ckpt.t7... Done!
# ____________________________________________________________________
#  1
#
# 0: 480x640 1 person, 0.0ms
# Speed: 0.0ms preprocess, 0.0ms inference, 10.9ms postprocess per image at shape (1, 3, 480, 640)
# Loading weights from ckpt.t7... Done!
# ____________________________________________________________________
#  1
#
# 0: 480x640 1 person, 10.0ms
# Speed: 0.0ms preprocess, 10.0ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
# Loading weights from ckpt.t7... Done!
# ____________________________________________________________________
#  1
#
# 0: 480x640 1 person, 8.7ms
# Speed: 1.8ms preprocess, 8.7ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
# Loading weights from ckpt.t7... Done!
# ____________________________________________________________________
#  1
#
# 0: 480x640 1 person, 10.0ms
# Speed: 0.0ms preprocess, 10.0ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
# Loading weights from ckpt.t7... Done!
# ____________________________________________________________________
#  1
#
# 0: 480x640 1 person, 9.4ms
# Speed: 1.7ms preprocess, 9.4ms inference, 1.1ms postprocess per image at shape (1, 3, 480, 640)
# Loading weights from ckpt.t7... Done!
# ____________________________________________________________________
#  1
#
# 0: 480x640 1 person, 10.0ms
# Speed: 0.0ms preprocess, 10.0ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
# Loading weights from ckpt.t7... Done!
# ____________________________________________________________________
#  1
#
# 0: 480x640 1 person, 0.0ms
# Speed: 0.0ms preprocess, 0.0ms inference, 9.5ms postprocess per image at shape (1, 3, 480, 640)
# Loading weights from ckpt.t7... Done!
# ____________________________________________________________________
#  1
#
# 0: 480x640 1 person, 16.2ms
# Speed: 0.0ms preprocess, 16.2ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
# Loading weights from ckpt.t7... Done!
# ____________________________________________________________________
#  1
#
# 0: 480x640 1 person, 9.2ms
# Speed: 0.0ms preprocess, 9.2ms inference, 0.7ms postprocess per image at shape (1, 3, 480, 640)
# Loading weights from ckpt.t7... Done!
# ____________________________________________________________________
#  1
#
# 0: 480x640 1 person, 3.3ms
# Speed: 0.1ms preprocess, 3.3ms inference, 6.9ms postprocess per image at shape (1, 3, 480, 640)
# Loading weights from ckpt.t7... Done!
# ____________________________________________________________________
#  1
#
# 0: 480x640 1 person, 7.9ms
# Speed: 0.0ms preprocess, 7.9ms inference, 5.4ms postprocess per image at shape (1, 3, 480, 640)
# Loading weights from ckpt.t7... Done!
# ____________________________________________________________________
#  1
#
# 0: 480x640 1 person, 10.0ms
# Speed: 0.0ms preprocess, 10.0ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
# Loading weights from ckpt.t7... Done!
# ____________________________________________________________________
#  1
#
# 0: 480x640 1 person, 10.7ms
# Speed: 0.0ms preprocess, 10.7ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
# Loading weights from ckpt.t7... Done!
# ____________________________________________________________________
#  1
#
# 0: 480x640 1 person, 3.0ms
# Speed: 0.0ms preprocess, 3.0ms inference, 7.0ms postprocess per image at shape (1, 3, 480, 640)
# Loading weights from ckpt.t7... Done!
# ____________________________________________________________________
#  1
#
# 0: 480x640 1 person, 6.9ms
# Speed: 2.9ms preprocess, 6.9ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
# Loading weights from ckpt.t7... Done!
# ____________________________________________________________________
#  1
#
# 0: 480x640 1 person, 10.2ms
# Speed: 0.0ms preprocess, 10.2ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
# Loading weights from ckpt.t7... Done!
# ____________________________________________________________________
#  1
#
# 0: 480x640 1 person, 8.0ms
# Speed: 0.0ms preprocess, 8.0ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
# Loading weights from ckpt.t7... Done!
# ____________________________________________________________________
#  1
#
# 0: 480x640 1 person, 9.5ms
# Speed: 0.0ms preprocess, 9.5ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
# Loading weights from ckpt.t7... Done!
# ____________________________________________________________________
#  1
#
# 0: 480x640 1 person, 10.1ms
# Speed: 0.0ms preprocess, 10.1ms inference, 5.6ms postprocess per image at shape (1, 3, 480, 640)
# Loading weights from ckpt.t7... Done!
# ____________________________________________________________________
#  1
#
# 0: 480x640 1 person, 10.0ms
# Speed: 0.0ms preprocess, 10.0ms inference, 0.7ms postprocess per image at shape (1, 3, 480, 640)
# Loading weights from ckpt.t7... Done!
# ____________________________________________________________________
#  1
#
# 0: 480x640 1 person, 13.4ms
# Speed: 0.0ms preprocess, 13.4ms inference, 1.6ms postprocess per image at shape (1, 3, 480, 640)
# Loading weights from ckpt.t7... Done!
# ____________________________________________________________________
#  1
#
# 0: 480x640 1 person, 7.1ms
# Speed: 1.7ms preprocess, 7.1ms inference, 2.4ms postprocess per image at shape (1, 3, 480, 640)
# Loading weights from ckpt.t7... Done!
# ____________________________________________________________________
#  1
#
# 0: 480x640 1 person, 10.6ms
# Speed: 0.0ms preprocess, 10.6ms inference, 1.1ms postprocess per image at shape (1, 3, 480, 640)
# Loading weights from ckpt.t7... Done!
# ____________________________________________________________________
#  1
#
# 0: 480x640 1 person, 9.5ms
# Speed: 0.0ms preprocess, 9.5ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
# Loading weights from ckpt.t7... Done!
# ____________________________________________________________________
#  1
#
# 0: 480x640 1 person, 0.0ms
# Speed: 0.0ms preprocess, 0.0ms inference, 10.0ms postprocess per image at shape (1, 3, 480, 640)
# Loading weights from ckpt.t7... Done!
# ____________________________________________________________________
#  1
#
# 0: 480x640 1 person, 10.4ms
# Speed: 0.0ms preprocess, 10.4ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
# Loading weights from ckpt.t7... Done!
# ____________________________________________________________________
#  1
#
# 0: 480x640 1 person, 10.7ms
# Speed: 3.1ms preprocess, 10.7ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
# Loading weights from ckpt.t7... Done!
# ____________________________________________________________________
#  1
#
# 0: 480x640 1 person, 0.0ms
# Speed: 0.0ms preprocess, 0.0ms inference, 10.9ms postprocess per image at shape (1, 3, 480, 640)
# Loading weights from ckpt.t7... Done!
# ____________________________________________________________________
#  1
#
# 0: 480x640 1 person, 9.8ms
# Speed: 0.0ms preprocess, 9.8ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
# Loading weights from ckpt.t7... Done!
# ____________________________________________________________________
#  1
#
# 0: 480x640 1 person, 7.4ms
# Speed: 0.6ms preprocess, 7.4ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
# Loading weights from ckpt.t7... Done!
# ____________________________________________________________________
#  1
#
# 0: 480x640 1 person, 13.0ms
# Speed: 0.0ms preprocess, 13.0ms inference, 3.8ms postprocess per image at shape (1, 3, 480, 640)
# Loading weights from ckpt.t7... Done!
# ____________________________________________________________________
#  1
#
# 0: 480x640 1 person, 10.3ms
# Speed: 0.0ms preprocess, 10.3ms inference, 2.1ms postprocess per image at shape (1, 3, 480, 640)
# Loading weights from ckpt.t7... Done!
# ____________________________________________________________________
#  1
#
# 0: 480x640 1 person, 6.0ms
# Speed: 0.0ms preprocess, 6.0ms inference, 4.5ms postprocess per image at shape (1, 3, 480, 640)
# Loading weights from ckpt.t7... Done!
# ____________________________________________________________________
#  1
#
# 0: 480x640 1 person, 0.0ms
# Speed: 0.0ms preprocess, 0.0ms inference, 11.2ms postprocess per image at shape (1, 3, 480, 640)
# Loading weights from ckpt.t7... Done!
# ____________________________________________________________________
#  1
#
# 0: 480x640 1 person, 8.7ms
# Speed: 0.0ms preprocess, 8.7ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
# Loading weights from ckpt.t7... Done!
# ____________________________________________________________________
#  1
#
# 0: 480x640 1 person, 7.6ms
# Speed: 0.0ms preprocess, 7.6ms inference, 6.9ms postprocess per image at shape (1, 3, 480, 640)
# Loading weights from ckpt.t7... Done!
# ____________________________________________________________________
#  1
#
# 0: 480x640 1 person, 8.6ms
# Speed: 0.0ms preprocess, 8.6ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
# Loading weights from ckpt.t7... Done!
# ____________________________________________________________________
#  1
#
# 0: 480x640 1 person, 10.0ms
# Speed: 0.0ms preprocess, 10.0ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
# Loading weights from ckpt.t7... Done!
# ____________________________________________________________________
#  1
#
# 0: 480x640 1 person, 7.0ms
# Speed: 1.4ms preprocess, 7.0ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
# Loading weights from ckpt.t7... Done!
# ____________________________________________________________________
#  1
#
# 0: 480x640 1 person, 0.0ms
# Speed: 3.0ms preprocess, 0.0ms inference, 7.5ms postprocess per image at shape (1, 3, 480, 640)
# Loading weights from ckpt.t7... Done!
# ____________________________________________________________________
#  1
#
# 0: 480x640 1 person, 7.2ms
# Speed: 2.7ms preprocess, 7.2ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
# Loading weights from ckpt.t7... Done!
# ____________________________________________________________________
#  1
#
# 0: 480x640 1 person, 11.2ms
# Speed: 3.1ms preprocess, 11.2ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
# Loading weights from ckpt.t7... Done!
# ____________________________________________________________________
#  1
#
# 0: 480x640 1 person, 6.6ms
# Speed: 1.4ms preprocess, 6.6ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
# Loading weights from ckpt.t7... Done!
# ____________________________________________________________________
#  1
#
# 0: 480x640 1 person, 10.0ms
# Speed: 0.0ms preprocess, 10.0ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
# Loading weights from ckpt.t7... Done!
# ____________________________________________________________________
#  1
#
# 0: 480x640 1 person, 5.9ms
# Speed: 3.6ms preprocess, 5.9ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
# Loading weights from ckpt.t7... Done!
# ____________________________________________________________________
#  1
#
# 0: 480x640 1 person, 13.2ms
# Speed: 0.0ms preprocess, 13.2ms inference, 0.5ms postprocess per image at shape (1, 3, 480, 640)
# Loading weights from ckpt.t7... Done!
# ____________________________________________________________________
#  1
#
# 0: 480x640 1 person, 7.4ms
# Speed: 2.2ms preprocess, 7.4ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
# Loading weights from ckpt.t7... Done!
# ____________________________________________________________________
#  1
#
# 0: 480x640 1 person, 9.3ms
# Speed: 0.0ms preprocess, 9.3ms inference, 2.1ms postprocess per image at shape (1, 3, 480, 640)
# Loading weights from ckpt.t7... Done!
# ____________________________________________________________________
#  1
#
# 0: 480x640 1 person, 6.1ms
# Speed: 0.0ms preprocess, 6.1ms inference, 4.0ms postprocess per image at shape (1, 3, 480, 640)
# Loading weights from ckpt.t7... Done!
# ____________________________________________________________________
#  1
#
# 0: 480x640 1 person, 12.4ms
# Speed: 0.0ms preprocess, 12.4ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
# Loading weights from ckpt.t7... Done!
# ____________________________________________________________________
#  1
#
# 0: 480x640 1 person, 14.2ms
# Speed: 0.0ms preprocess, 14.2ms inference, 1.1ms postprocess per image at shape (1, 3, 480, 640)
# Loading weights from ckpt.t7... Done!
# ____________________________________________________________________
#  1
#
# 0: 480x640 1 person, 10.0ms
# Speed: 0.0ms preprocess, 10.0ms inference, 10.0ms postprocess per image at shape (1, 3, 480, 640)
# Loading weights from ckpt.t7... Done!
# ____________________________________________________________________
#  1
#
# 0: 480x640 1 person, 9.0ms
# Speed: 0.0ms preprocess, 9.0ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
# Loading weights from ckpt.t7... Done!
# ____________________________________________________________________
#  1
#
# 0: 480x640 1 person, 10.5ms
# Speed: 0.0ms preprocess, 10.5ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
# Loading weights from ckpt.t7... Done!
# ____________________________________________________________________
#  1
#
# 0: 480x640 1 person, 16.6ms
# Speed: 0.0ms preprocess, 16.6ms inference, 3.5ms postprocess per image at shape (1, 3, 480, 640)
# Loading weights from ckpt.t7... Done!
# ____________________________________________________________________
#  1
#
# 0: 480x640 1 person, 15.0ms
# Speed: 0.0ms preprocess, 15.0ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
# Loading weights from ckpt.t7... Done!
# ____________________________________________________________________
#  1
#
# 0: 480x640 1 person, 10.2ms
# Speed: 0.0ms preprocess, 10.2ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
# Loading weights from ckpt.t7... Done!
# ____________________________________________________________________
#  1
#
# 0: 480x640 1 person, 10.0ms
# Speed: 0.0ms preprocess, 10.0ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
# Loading weights from ckpt.t7... Done!
# ____________________________________________________________________
#  1
#
# 0: 480x640 1 person, 11.4ms
# Speed: 0.0ms preprocess, 11.4ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
# Loading weights from ckpt.t7... Done!
# ____________________________________________________________________
#  1
#
# 0: 480x640 1 person, 9.0ms
# Speed: 1.0ms preprocess, 9.0ms inference, 2.1ms postprocess per image at shape (1, 3, 480, 640)
# Loading weights from ckpt.t7... Done!
# ____________________________________________________________________
#  1
#
# 0: 480x640 1 person, 8.4ms
# Speed: 0.0ms preprocess, 8.4ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
# Loading weights from ckpt.t7... Done!
# ____________________________________________________________________
#  1
#
# 0: 480x640 1 person, 10.0ms
# Speed: 0.0ms preprocess, 10.0ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
# Loading weights from ckpt.t7... Done!
# ____________________________________________________________________
#  1
#
# 0: 480x640 1 person, 11.0ms
# Speed: 0.0ms preprocess, 11.0ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
# Loading weights from ckpt.t7... Done!
# ____________________________________________________________________
#  1
#
# 0: 480x640 1 person, 5.9ms
# Speed: 1.1ms preprocess, 5.9ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
# Loading weights from ckpt.t7... Done!
# ____________________________________________________________________
#  1
#
# 0: 480x640 1 person, 10.0ms
# Speed: 0.0ms preprocess, 10.0ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
# Loading weights from ckpt.t7... Done!
# ____________________________________________________________________
#  1
#
# 0: 480x640 1 person, 10.1ms
# Speed: 0.0ms preprocess, 10.1ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
# Loading weights from ckpt.t7... Done!
# ____________________________________________________________________
#  1
#
# 0: 480x640 1 person, 10.6ms
# Speed: 0.0ms preprocess, 10.6ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
# Loading weights from ckpt.t7... Done!
# ____________________________________________________________________
#  1
#
# 0: 480x640 1 person, 6.8ms
# Speed: 3.5ms preprocess, 6.8ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
# Loading weights from ckpt.t7... Done!
# ____________________________________________________________________
#  1
#
# 0: 480x640 1 person, 6.9ms
# Speed: 0.0ms preprocess, 6.9ms inference, 3.5ms postprocess per image at shape (1, 3, 480, 640)
# Loading weights from ckpt.t7... Done!
# ____________________________________________________________________
#  1
#
# 0: 480x640 1 person, 0.0ms
# Speed: 0.0ms preprocess, 0.0ms inference, 10.6ms postprocess per image at shape (1, 3, 480, 640)
# Loading weights from ckpt.t7... Done!
# ____________________________________________________________________
#  1
#
# 0: 480x640 1 person, 8.8ms
# Speed: 0.0ms preprocess, 8.8ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
# Loading weights from ckpt.t7... Done!
# ____________________________________________________________________
#  1
#
# 0: 480x640 1 person, 7.5ms
# Speed: 0.4ms preprocess, 7.5ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
# Loading weights from ckpt.t7... Done!
# ____________________________________________________________________
#  1
#
# 0: 480x640 1 person, 10.0ms
# Speed: 0.0ms preprocess, 10.0ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
# Loading weights from ckpt.t7... Done!
# ____________________________________________________________________
#  1
#
# 0: 480x640 1 person, 10.0ms
# Speed: 0.0ms preprocess, 10.0ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
# Loading weights from ckpt.t7... Done!
# ____________________________________________________________________
#  1
#
# 0: 480x640 1 person, 10.7ms
# Speed: 0.0ms preprocess, 10.7ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
# Loading weights from ckpt.t7... Done!
# ____________________________________________________________________
#  1
#
# 0: 480x640 1 person, 12.2ms
# Speed: 0.0ms preprocess, 12.2ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
# Loading weights from ckpt.t7... Done!
# ____________________________________________________________________
#  1
#
# 0: 480x640 1 person, 7.7ms
# Speed: 0.0ms preprocess, 7.7ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
# Loading weights from ckpt.t7... Done!
# ____________________________________________________________________
#  1
#
# 0: 480x640 1 person, 14.9ms
# Speed: 0.0ms preprocess, 14.9ms inference, 2.6ms postprocess per image at shape (1, 3, 480, 640)
# Loading weights from ckpt.t7... Done!
# ____________________________________________________________________
#  1
#
# 0: 480x640 1 person, 9.2ms
# Speed: 0.0ms preprocess, 9.2ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
# Loading weights from ckpt.t7... Done!
# ____________________________________________________________________
#  1
#
# 0: 480x640 1 person, 0.0ms
# Speed: 0.0ms preprocess, 0.0ms inference, 10.0ms postprocess per image at shape (1, 3, 480, 640)
# Loading weights from ckpt.t7... Done!
# ____________________________________________________________________
#  1
#
# 0: 480x640 1 person, 8.5ms
# Speed: 0.0ms preprocess, 8.5ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
# Loading weights from ckpt.t7... Done!
# ____________________________________________________________________
#  1
#
# 0: 480x640 1 person, 10.0ms
# Speed: 0.0ms preprocess, 10.0ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
# Loading weights from ckpt.t7... Done!
# ____________________________________________________________________
#  1
#
# 0: 480x640 1 person, 10.0ms
# Speed: 0.0ms preprocess, 10.0ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
# Loading weights from ckpt.t7... Done!
# ____________________________________________________________________
#  1
#
# 0: 480x640 1 person, 7.2ms
# Speed: 2.0ms preprocess, 7.2ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
# Loading weights from ckpt.t7... Done!
# ____________________________________________________________________
#  1
#
# 0: 480x640 1 person, 10.0ms
# Speed: 0.0ms preprocess, 10.0ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
# Loading weights from ckpt.t7... Done!
# ____________________________________________________________________
#  1
#
# 0: 480x640 1 person, 14.6ms
# Speed: 0.0ms preprocess, 14.6ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
# Loading weights from ckpt.t7... Done!
# ____________________________________________________________________
#  1
#
# 0: 480x640 1 person, 10.0ms
# Speed: 0.0ms preprocess, 10.0ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
# Loading weights from ckpt.t7... Done!
# ____________________________________________________________________
#  1
#
# 0: 480x640 1 person, 11.5ms
# Speed: 0.0ms preprocess, 11.5ms inference, 1.1ms postprocess per image at shape (1, 3, 480, 640)
# Loading weights from ckpt.t7... Done!
# ____________________________________________________________________
#  1
#
# 0: 480x640 1 person, 10.0ms
# Speed: 0.0ms preprocess, 10.0ms inference, 3.6ms postprocess per image at shape (1, 3, 480, 640)
# Loading weights from ckpt.t7... Done!
# ____________________________________________________________________
#  1
#
# 0: 480x640 1 person, 8.7ms
# Speed: 3.0ms preprocess, 8.7ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
# Loading weights from ckpt.t7... Done!
# ____________________________________________________________________
#  1
#
# 0: 480x640 1 person, 10.0ms
# Speed: 0.0ms preprocess, 10.0ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
# Loading weights from ckpt.t7... Done!
# ____________________________________________________________________
#  1
#
# 0: 480x640 1 person, 0.0ms
# Speed: 0.0ms preprocess, 0.0ms inference, 10.0ms postprocess per image at shape (1, 3, 480, 640)
# Loading weights from ckpt.t7... Done!
# ____________________________________________________________________
#  1
#
# 0: 480x640 1 person, 10.7ms
# Speed: 0.0ms preprocess, 10.7ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
# Loading weights from ckpt.t7... Done!
# ____________________________________________________________________
#  1
#
# 0: 480x640 1 person, 10.9ms
# Speed: 0.0ms preprocess, 10.9ms inference, 2.2ms postprocess per image at shape (1, 3, 480, 640)
# Loading weights from ckpt.t7... Done!
# ____________________________________________________________________
#  1
#
# 0: 480x640 1 person, 6.0ms
# Speed: 2.6ms preprocess, 6.0ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
# Loading weights from ckpt.t7... Done!
# ____________________________________________________________________
#  1
#
# 0: 480x640 1 person, 8.0ms
# Speed: 0.0ms preprocess, 8.0ms inference, 3.1ms postprocess per image at shape (1, 3, 480, 640)
# Loading weights from ckpt.t7... Done!
# ____________________________________________________________________
#  1
#
# 0: 480x640 1 person, 10.0ms
# Speed: 0.0ms preprocess, 10.0ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
# Loading weights from ckpt.t7... Done!
# ____________________________________________________________________
#  1
#
# 0: 480x640 1 person, 10.0ms
# Speed: 0.0ms preprocess, 10.0ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
# Loading weights from ckpt.t7... Done!
# ____________________________________________________________________
#  1
#
# 0: 480x640 1 person, 13.7ms
# Speed: 0.0ms preprocess, 13.7ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
# Loading weights from ckpt.t7... Done!
# ____________________________________________________________________
#  1
#
# 0: 480x640 1 person, 9.6ms
# Speed: 0.0ms preprocess, 9.6ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
# Loading weights from ckpt.t7... Done!
# ____________________________________________________________________
#  1
#
# 0: 480x640 1 person, 0.0ms
# Speed: 0.0ms preprocess, 0.0ms inference, 10.0ms postprocess per image at shape (1, 3, 480, 640)
# Loading weights from ckpt.t7... Done!
# ____________________________________________________________________
#  1
#
# 0: 480x640 1 person, 10.0ms
# Speed: 0.0ms preprocess, 10.0ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
# Loading weights from ckpt.t7... Done!
# ____________________________________________________________________
#  1
#
# 0: 480x640 1 person, 6.7ms
# Speed: 2.1ms preprocess, 6.7ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
# Loading weights from ckpt.t7... Done!
# ____________________________________________________________________
#  1
#
# 0: 480x640 1 person, 0.0ms
# Speed: 0.0ms preprocess, 0.0ms inference, 10.0ms postprocess per image at shape (1, 3, 480, 640)
# Loading weights from ckpt.t7... Done!
# ____________________________________________________________________
#  1
#
# 0: 480x640 1 person, 0.0ms
# Speed: 0.0ms preprocess, 0.0ms inference, 10.0ms postprocess per image at shape (1, 3, 480, 640)
# Loading weights from ckpt.t7... Done!
# ____________________________________________________________________
#  1
#
# 0: 480x640 1 person, 9.7ms
# Speed: 0.0ms preprocess, 9.7ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
# ...
# Speed: 0.0ms preprocess, 10.1ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
# Loading weights from ckpt.t7... Done!
# ____________________________________________________________________
#  1
#
# 0: 480x640 1 person, 8.5ms
# Speed: 0.0ms preprocess, 8.5ms inference, 4.0ms postprocess per image at shape (1, 3, 480, 640)
# Loading weights from ckpt.t7... Done!
# ____________________________________________________________________
#  1
#
# 0: 480x640 1 person, 10.1ms
# Speed: 0.0ms preprocess, 10.1ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
# Loading weights from ckpt.t7... Done!
# ____________________________________________________________________
#  1
#
# 0: 480x640 1 person, 10.0ms
# Speed: 0.0ms preprocess, 10.0ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
# Loading weights from ckpt.t7... Done!
# ____________________________________________________________________
#  1
#
# 0: 480x640 1 person, 10.0ms
# Speed: 0.0ms preprocess, 10.0ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
# Loading weights from ckpt.t7... Done!
# ____________________________________________________________________
#  1
#
# 0: 480x640 1 person, 11.1ms
# Speed: 0.0ms preprocess, 11.1ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
# Loading weights from ckpt.t7... Done!
# ____________________________________________________________________
#  1
#
# 0: 480x640 1 person, 11.4ms
# Speed: 0.0ms preprocess, 11.4ms inference, 5.6ms postprocess per image at shape (1, 3, 480, 640)
# Loading weights from ckpt.t7... Done!
# ____________________________________________________________________
#  1
#
# 0: 480x640 1 person, 12.3ms
# Speed: 0.0ms preprocess, 12.3ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
# Loading weights from ckpt.t7... Done!
# ____________________________________________________________________
#  1
#
# 0: 480x640 1 person, 10.1ms
# Speed: 0.0ms preprocess, 10.1ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
# Loading weights from ckpt.t7... Done!
# ____________________________________________________________________
#  1
#
# 0: 480x640 1 person, 10.1ms
# Speed: 0.0ms preprocess, 10.1ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
# Loading weights from ckpt.t7... Done!
# ____________________________________________________________________
#  1
#
# 0: 480x640 1 person, 7.6ms
# Speed: 2.3ms preprocess, 7.6ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
# Loading weights from ckpt.t7... Done!
# ____________________________________________________________________
#  1
#
# 0: 480x640 1 person, 10.0ms
# Speed: 0.0ms preprocess, 10.0ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
# Loading weights from ckpt.t7... Done!
# ____________________________________________________________________
#  1
#
# 0: 480x640 1 person, 8.2ms
# Speed: 0.1ms preprocess, 8.2ms inference, 1.9ms postprocess per image at shape (1, 3, 480, 640)
# Loading weights from ckpt.t7... Done!
# ____________________________________________________________________
#  1
#
# 0: 480x640 1 person, 10.0ms
# Speed: 0.0ms preprocess, 10.0ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
# Loading weights from ckpt.t7... Done!
# ____________________________________________________________________
#  1
#
# 0: 480x640 1 person, 8.0ms
# Speed: 2.0ms preprocess, 8.0ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
# Loading weights from ckpt.t7... Done!
# ____________________________________________________________________
#  1
#
# 0: 480x640 1 person, 12.9ms
# Speed: 0.0ms preprocess, 12.9ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
# Loading weights from ckpt.t7... Done!
# ____________________________________________________________________
#  1
#
# 0: 480x640 1 person, 10.5ms
# Speed: 0.0ms preprocess, 10.5ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
# Loading weights from ckpt.t7... Done!
# ____________________________________________________________________
#  1
#
# 0: 480x640 1 person, 10.0ms
# Speed: 0.0ms preprocess, 10.0ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
# Loading weights from ckpt.t7... Done!
# ____________________________________________________________________
#  1
#
# 0: 480x640 1 person, 10.0ms
# Speed: 0.0ms preprocess, 10.0ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
# Loading weights from ckpt.t7... Done!
# ____________________________________________________________________
#  1
#
# 0: 480x640 1 person, 10.0ms
# Speed: 0.0ms preprocess, 10.0ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
# Loading weights from ckpt.t7... Done!
# ____________________________________________________________________
#  1
#
# 0: 480x640 1 person, 10.1ms
# Speed: 0.0ms preprocess, 10.1ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
# Loading weights from ckpt.t7... Done!
# ____________________________________________________________________
#  1
#
# 0: 480x640 1 person, 5.8ms
# Speed: 3.4ms preprocess, 5.8ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
# Loading weights from ckpt.t7... Done!
# ____________________________________________________________________
#  1
#
# 0: 480x640 1 person, 10.0ms
# Speed: 0.0ms preprocess, 10.0ms inference, 1.9ms postprocess per image at shape (1, 3, 480, 640)
# Loading weights from ckpt.t7... Done!
# ____________________________________________________________________
#  1
#
# 0: 480x640 1 person, 12.3ms
# Speed: 0.0ms preprocess, 12.3ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
# Loading weights from ckpt.t7... Done!
# ____________________________________________________________________
#  1
#
# 0: 480x640 1 person, 10.9ms
# Speed: 0.0ms preprocess, 10.9ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
# Loading weights from ckpt.t7... Done!
# ____________________________________________________________________
#  1
#
# 0: 480x640 1 person, 12.1ms
# Speed: 0.0ms preprocess, 12.1ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
# Loading weights from ckpt.t7... Done!
# ____________________________________________________________________
#  1
#
# 0: 480x640 1 person, 6.5ms
# Speed: 1.8ms preprocess, 6.5ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
# Loading weights from ckpt.t7... Done!
# ____________________________________________________________________
#  1
#
# 0: 480x640 1 person, 0.0ms
# Speed: 0.0ms preprocess, 0.0ms inference, 10.0ms postprocess per image at shape (1, 3, 480, 640)
# Loading weights from ckpt.t7... Done!
# ____________________________________________________________________
#  1
#
# 0: 480x640 1 person, 7.0ms
# Speed: 2.0ms preprocess, 7.0ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
# Loading weights from ckpt.t7... Done!
# ____________________________________________________________________
#  1
#
# 0: 480x640 1 person, 2.9ms
# Speed: 2.5ms preprocess, 2.9ms inference, 5.0ms postprocess per image at shape (1, 3, 480, 640)
# Loading weights from ckpt.t7... Done!
# ____________________________________________________________________
#  1
#
# 0: 480x640 1 person, 0.0ms
# Speed: 0.0ms preprocess, 0.0ms inference, 10.8ms postprocess per image at shape (1, 3, 480, 640)
# Loading weights from ckpt.t7... Done!
# ____________________________________________________________________
#  1
#
# 0: 480x640 1 person, 13.2ms
# Speed: 0.0ms preprocess, 13.2ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
# Loading weights from ckpt.t7... Done!
# ____________________________________________________________________
#  1
#
# 0: 480x640 1 person, 7.7ms
# Speed: 2.6ms preprocess, 7.7ms inference, 1.8ms postprocess per image at shape (1, 3, 480, 640)
# Loading weights from ckpt.t7... Done!
# ____________________________________________________________________
#  1
#
# 0: 480x640 1 person, 12.8ms
# Speed: 0.0ms preprocess, 12.8ms inference, 5.5ms postprocess per image at shape (1, 3, 480, 640)
# Loading weights from ckpt.t7... Done!
# ____________________________________________________________________
#  1
#
# 0: 480x640 1 person, 6.5ms
# Speed: 2.1ms preprocess, 6.5ms inference, 3.1ms postprocess per image at shape (1, 3, 480, 640)
# Loading weights from ckpt.t7... Done!
# ____________________________________________________________________
#  1
#
# 0: 480x640 1 person, 6.3ms
# Speed: 0.0ms preprocess, 6.3ms inference, 5.1ms postprocess per image at shape (1, 3, 480, 640)
# Loading weights from ckpt.t7... Done!
# ____________________________________________________________________
#  1
#
# 0: 480x640 1 person, 10.0ms
# Speed: 0.0ms preprocess, 10.0ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
# Loading weights from ckpt.t7... Done!
# ____________________________________________________________________
#  1
#
# 0: 480x640 1 person, 17.9ms
# Speed: 0.0ms preprocess, 17.9ms inference, 2.3ms postprocess per image at shape (1, 3, 480, 640)
# Loading weights from ckpt.t7... Done!
# ____________________________________________________________________
#  1
#
# 0: 480x640 1 person, 8.8ms
# Speed: 0.0ms preprocess, 8.8ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
# Loading weights from ckpt.t7... Done!
# ____________________________________________________________________
#  1
#
# 0: 480x640 1 person, 10.1ms
# Speed: 0.0ms preprocess, 10.1ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
# Loading weights from ckpt.t7... Done!
# ____________________________________________________________________
#  1
#
# 0: 480x640 1 person, 13.2ms
# Speed: 0.0ms preprocess, 13.2ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
# Loading weights from ckpt.t7... Done!
# ____________________________________________________________________
#  1
#
# 0: 480x640 1 person, 10.0ms
# Speed: 0.0ms preprocess, 10.0ms inference, 2.9ms postprocess per image at shape (1, 3, 480, 640)
# Loading weights from ckpt.t7... Done!
# ____________________________________________________________________
#  1
#
# 0: 480x640 1 person, 10.0ms
# Speed: 0.0ms preprocess, 10.0ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
# Loading weights from ckpt.t7... Done!
# ____________________________________________________________________
#  1
#
# 0: 480x640 1 person, 6.9ms
# Speed: 3.5ms preprocess, 6.9ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
# Loading weights from ckpt.t7... Done!
# ____________________________________________________________________
#  1
#
# 0: 480x640 1 person, 10.5ms
# Speed: 3.9ms preprocess, 10.5ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
# Loading weights from ckpt.t7... Done!
# ____________________________________________________________________
#  1
#
# 0: 480x640 1 person, 10.0ms
# Speed: 0.0ms preprocess, 10.0ms inference, 4.5ms postprocess per image at shape (1, 3, 480, 640)
# Loading weights from ckpt.t7... Done!
# ____________________________________________________________________
#  1
#
# 0: 480x640 1 person, 10.0ms
# Speed: 0.0ms preprocess, 10.0ms inference, 5.5ms postprocess per image at shape (1, 3, 480, 640)
# Loading weights from ckpt.t7... Done!
# ____________________________________________________________________
#  1
#
# 0: 480x640 1 person, 8.5ms
# Speed: 0.0ms preprocess, 8.5ms inference, 2.1ms postprocess per image at shape (1, 3, 480, 640)
# Loading weights from ckpt.t7... Done!
# ____________________________________________________________________
#  1
#
# 0: 480x640 1 person, 9.6ms
# Speed: 0.0ms preprocess, 9.6ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
# Loading weights from ckpt.t7... Done!
# ____________________________________________________________________
#  1
#
# 0: 480x640 1 person, 8.8ms
# Speed: 0.0ms preprocess, 8.8ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
# Loading weights from ckpt.t7... Done!
# ____________________________________________________________________
#  1
#
# 0: 480x640 1 person, 6.8ms
# Speed: 4.0ms preprocess, 6.8ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
# Loading weights from ckpt.t7... Done!
# ____________________________________________________________________
#  1
#
# 0: 480x640 1 person, 10.0ms
# Speed: 0.0ms preprocess, 10.0ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
# Loading weights from ckpt.t7... Done!
# ____________________________________________________________________
#  1
#
# 0: 480x640 1 person, 9.0ms
# Speed: 2.9ms preprocess, 9.0ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
# Loading weights from ckpt.t7... Done!
# ____________________________________________________________________
#  1
#
# 0: 480x640 1 person, 5.8ms
# Speed: 0.0ms preprocess, 5.8ms inference, 3.0ms postprocess per image at shape (1, 3, 480, 640)
# Loading weights from ckpt.t7... Done!
# ____________________________________________________________________
#  1
#
# 0: 480x640 1 person, 10.0ms
# Speed: 0.0ms preprocess, 10.0ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
# Loading weights from ckpt.t7... Done!
# ____________________________________________________________________
#  1
#
# 0: 480x640 1 person, 10.6ms
# Speed: 0.0ms preprocess, 10.6ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
# Loading weights from ckpt.t7... Done!
# ____________________________________________________________________
#  1
#
# 0: 480x640 1 person, 10.0ms
# Speed: 0.0ms preprocess, 10.0ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
# Loading weights from ckpt.t7... Done!
# ____________________________________________________________________
#  1
#
# 0: 480x640 2 persons, 15.2ms
# Speed: 0.9ms preprocess, 15.2ms inference, 1.1ms postprocess per image at shape (1, 3, 480, 640)
# Loading weights from ckpt.t7... Done!
# ---------------------------------------------------------------------------
# error                                     Traceback (most recent call last)
# Cell In[6], line 64
#      62     cap.release()
#      63     cv2.destroyAllWindows()
# ---> 64 object_tracking()
#
# Cell In[6], line 38, in object_tracking()
#      36 names = np.array(labels)
#      37 scores = np.array(scores)
# ---> 38 features = np.array(crop_image(frame, boxes))
#      39 detections = [Detection(bbox, score, class_name, feature) for bbox, score, class_name, feature in zip(boxes, scores, names, features)]
#      41 tracker.predict()
#
# Cell In[5], line 10, in crop_image(image, bboxes)
#       8     im_crops.append(img)
#       9 if im_crops:
# ---> 10     features = encoder(im_crops)
#      11 else:
#      12     features = np.array([])
#
# File d:\Multiple-object-tracking-use-deep-sort\image_encode.py:133, in Extractor.__call__(self, im_crops)
#     132 def __call__(self, im_crops):
# --> 133     im_batch = self._preprocess(im_crops)
#     134     with torch.no_grad():
#     135         im_batch = im_batch.to(self.device)
#
# File d:\Multiple-object-tracking-use-deep-sort\image_encode.py:128, in Extractor._preprocess(self, im_crops)
#     125 def _resize(im, size):
#     126     return cv2.resize(im.astype(np.float32)/255., size)
# --> 128 im_batch = torch.cat([self.norm(_resize(im, self.size)).unsqueeze(0) for im in im_crops], dim=0).float()
#     129 return im_batch
#
# File d:\Multiple-object-tracking-use-deep-sort\image_encode.py:128, in <listcomp>(.0)
#     125 def _resize(im, size):
#     126     return cv2.resize(im.astype(np.float32)/255., size)
# --> 128 im_batch = torch.cat([self.norm(_resize(im, self.size)).unsqueeze(0) for im in im_crops], dim=0).float()
#     129 return im_batch
#
# File d:\Multiple-object-tracking-use-deep-sort\image_encode.py:126, in Extractor._preprocess.<locals>._resize(im, size)
#     125 def _resize(im, size):
# --> 126     return cv2.resize(im.astype(np.float32)/255., size)
#
# error: OpenCV(4.9.0) D:\a\opencv-python\opencv-python\opencv\modules\imgproc\src\resize.cpp:4152: error: (-215:Assertion failed) !ssize.empty() in function 'cv::resize'
# The Kernel crashed while executing code in the current cell or a previous cell.
#
# Please review the code in the cell(s) to identify a possible cause of the failure.
#
# Click <a href='https://aka.ms/vscodeJupyterKernelCrash'>here</a> for more info.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.
